# %% [markdown]
# # Filename: Adversarial_Dimensionality(NoLvsSGD)
# ## Load file from checkpoint_submission folder attached
# ### Adv_space_SGD_epsilon_8.h5 - Adversarial Dimension of SGD Model calculated in ResNet18_SGD file
# ### Adv_space_NoL_epsilon_8.h5 - Adversarial Dimension of NoL Model calculated in ResNet18_NoL file

# %%
from __future__ import print_function
import torch
state= torch.load('./checkpoint_submission/Adv_space_SGD_epsilon_8.h5')
x=state['x']
y=state['y']
state1= torch.load('./checkpoint_submission/Adv_space_NoL_epslion_8.h5')
x1=state1['x']
y1=state1['y']

# %% [markdown]
# ### Adversarial dimesnion plotted for epsilon = 8/255 adversaries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x[2:],y[2:],'-+')
plt.plot(x1[2:],y1[2:],'--o')
plt.legend(['SGD', 'NoL'], fontsize='x-large')
plt.xlabel('k Orthogonal Vectors', fontsize = 'xx-large')
plt.ylabel('Error Probability', fontsize = 'xx-large')
# Out:
# Text(0,0.5,'Error Probability')
